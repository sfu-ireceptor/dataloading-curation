# %% [markdown]
# <h1 align='center'>Checking File Names Match Run IDs in Metadata Spreadsheets</h1>
#
# <h4 align='center'>iReceptor $\mid$Notebook Author: Laura Gutierrez Funderburk $\mid$September 2018</h4>
#
# <h4 align='center'>Supervised by: Felix Breden, Jamie Scott, Brian Corrie</h4>
#
# <h2 align='center'>Abstract</h2>
#
# In this notebook we will write a few Python functions whose purpose are to check that file names match the appropriate run_id. Note that this can be extended on other columns.
#
# <h2 align='center'>Steps</h2>
#
# We identify two main steps to tackle in this problem
#
# 1) Need to check how many of the four File Name entries have a value other than NA
#
# 2) Once identified, verify that Run Ids match file names on a per-row basis. Note that one needs to be careful with entries having multiple files.
#
# <h2 align='center'>Begin</h2>
#
# We begin by importing Python libraries. For this notebook, we only need the Pandas module.

# %%
# Import libraries
import pandas as pd

# %% [markdown]
# We then indicate where to locate our metadata spreadsheets directory and files.

# %%
# Where metadata spreadsheets are
papers_dir = "./Metadata_spreadsheets/"
airr_dir = "./airr-standards/specs/"

# Metadata spreadsheets names
Zvy = papers_dir + "Zvyagin_Mamedov_2017.xlsx"
Mun = papers_dir + "Munson_2016.xlsx"
Mic = papers_dir + "michaeli_tabibian_metadata Aug 14.xlsx"
Cha = papers_dir + "Chang_2016.xlsx"
Pal = papers_dir + "Palanichamy_2014_Jun_14.xlsx"

# %% [markdown]
# Let us do our first example. We will pick the Munson metadata spreadsheet and will then generalize via a function. '

# %%
# Example 1:
#  Read Excel sheet and store as Pandas DataFrame

pd_Zvy = pd.read_excel(Mun)
pd_Zvy
# Out:
#    bioproject_id                                       project_name  \
# 0   PRJNA321261   Identification of shared TCR sequences from T ...
# 1   PRJNA321261   Identification of shared TCR sequences from T ...
# 2   PRJNA321261   Identification of shared TCR sequences from T ...
# 3   PRJNA321261   Identification of shared TCR sequences from T ...
# 4   PRJNA321261   Identification of shared TCR sequences from T ...
# 5   PRJNA321261   Identification of shared TCR sequences from T ...
# 6   PRJNA321261   Identification of shared TCR sequences from T ...
# 7   PRJNA321261   Identification of shared TCR sequences from T ...
# 8   PRJNA321261   Identification of shared TCR sequences from T ...
# 9   PRJNA321261   Identification of shared TCR sequences from T ...
# 10  PRJNA321261   Identification of shared TCR sequences from T ...
# 11  PRJNA321261   Identification of shared TCR sequences from T ...
# 12  PRJNA321261   Identification of shared TCR sequences from T ...
# 13  PRJNA321261   Identification of shared TCR sequences from T ...
# 14  PRJNA321261   Identification of shared TCR sequences from T ...
# 15  PRJNA321261   Identification of shared TCR sequences from T ...
# 16  PRJNA321261   Identification of shared TCR sequences from T ...
# 17  PRJNA321261   Identification of shared TCR sequences from T ...
# 18  PRJNA321261   Identification of shared TCR sequences from T ...
# 19  PRJNA321261   Identification of shared TCR sequences from T ...
# 20  PRJNA321261   Identification of shared TCR sequences from T ...
# 21  PRJNA321261   Identification of shared TCR sequences from T ...
# 22  PRJNA321261   Identification of shared TCR sequences from T ...
# 23  PRJNA321261   Identification of shared TCR sequences from T ...
# 24  PRJNA321261   Identification of shared TCR sequences from T ...
# 25  PRJNA321261   Identification of shared TCR sequences from T ...
# 26  PRJNA321261   Identification of shared TCR sequences from T ...
# 27  PRJNA321261   Identification of shared TCR sequences from T ...
# 28  PRJNA321261   Identification of shared TCR sequences from T ...
# 29  PRJNA321261   Identification of shared TCR sequences from T ...
# 30  PRJNA321261   Identification of shared TCR sequences from T ...
#
#    study_description inclusion_exclusion_criteria  \
# 0       Cancer Study      Inclusion breast cancer
# 1       Cancer Study      Inclusion breast cancer
# 2       Cancer Study      Inclusion breast cancer
# 3       Cancer Study      Inclusion breast cancer
# 4       Cancer Study      Inclusion breast cancer
# 5       Cancer Study      Inclusion breast cancer
# 6       Cancer Study      Inclusion breast cancer
# 7       Cancer Study      Inclusion breast cancer
# 8       Cancer Study      Inclusion breast cancer
# 9       Cancer Study      Inclusion breast cancer
# 10      Cancer Study      Inclusion breast cancer
# 11      Cancer Study      Inclusion breast cancer
# 12      Cancer Study      Inclusion breast cancer
# 13      Cancer Study      Inclusion breast cancer
# 14      Cancer Study      Inclusion breast cancer
# 15      Cancer Study      Inclusion breast cancer
# 16      Cancer Study      Inclusion breast cancer
# 17      Cancer Study      Inclusion breast cancer
# 18      Cancer Study      Inclusion breast cancer
# 19      Cancer Study      Inclusion breast cancer
# 20      Cancer Study      Inclusion breast cancer
# 21      Cancer Study      Inclusion breast cancer
# 22      Cancer Study      Inclusion breast cancer
# 23      Cancer Study      Inclusion breast cancer
# 24      Cancer Study      Inclusion breast cancer
# 25      Cancer Study      Inclusion breast cancer
# 26      Cancer Study      Inclusion breast cancer
# 27      Cancer Study      Inclusion breast cancer
# 28      Cancer Study      Inclusion breast cancer
# 29      Cancer Study      Inclusion breast cancer
# 30      Cancer Study      Inclusion breast cancer
#
#                                                grants  \
# 0   Department of Defense Congressionally Directed...
# 1   Department of Defense Congressionally Directed...
# 2   Department of Defense Congressionally Directed...
# 3   Department of Defense Congressionally Directed...
# 4   Department of Defense Congressionally Directed...
# 5   Department of Defense Congressionally Directed...
# 6   Department of Defense Congressionally Directed...
# 7   Department of Defense Congressionally Directed...
# 8   Department of Defense Congressionally Directed...
# 9   Department of Defense Congressionally Directed...
# 10  Department of Defense Congressionally Directed...
# 11  Department of Defense Congressionally Directed...
# 12  Department of Defense Congressionally Directed...
# 13  Department of Defense Congressionally Directed...
# 14  Department of Defense Congressionally Directed...
# 15  Department of Defense Congressionally Directed...
# 16  Department of Defense Congressionally Directed...
# 17  Department of Defense Congressionally Directed...
# 18  Department of Defense Congressionally Directed...
# 19  Department of Defense Congressionally Directed...
# 20  Department of Defense Congressionally Directed...
# 21  Department of Defense Congressionally Directed...
# 22  Department of Defense Congressionally Directed...
# 23  Department of Defense Congressionally Directed...
# 24  Department of Defense Congressionally Directed...
# 25  Department of Defense Congressionally Directed...
# 26  Department of Defense Congressionally Directed...
# 27  Department of Defense Congressionally Directed...
# 28  Department of Defense Congressionally Directed...
# 29  Department of Defense Congressionally Directed...
# 30  Department of Defense Congressionally Directed...
#
#                                          collected_by  \
# 0   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 1   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 2   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 3   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 4   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 5   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 6   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 7   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 8   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 9   kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 10  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 11  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 12  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 13  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 14  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 15  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 16  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 17  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 18  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 19  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 20  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 21  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 22  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 23  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 24  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 25  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 26  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 27  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 28  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 29  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
# 30  kapplerj@njhealth.org   jill.slanksy@ucdenver.edu
#
#                                      lab_name  \
# 0   Department of Immunology and Microbiology
# 1   Department of Immunology and Microbiology
# 2   Department of Immunology and Microbiology
# 3   Department of Immunology and Microbiology
# 4   Department of Immunology and Microbiology
# 5   Department of Immunology and Microbiology
# 6   Department of Immunology and Microbiology
# 7   Department of Immunology and Microbiology
# 8   Department of Immunology and Microbiology
# 9   Department of Immunology and Microbiology
# 10  Department of Immunology and Microbiology
# 11  Department of Immunology and Microbiology
# 12  Department of Immunology and Microbiology
# 13  Department of Immunology and Microbiology
# 14  Department of Immunology and Microbiology
# 15  Department of Immunology and Microbiology
# 16  Department of Immunology and Microbiology
# 17  Department of Immunology and Microbiology
# 18  Department of Immunology and Microbiology
# 19  Department of Immunology and Microbiology
# 20  Department of Immunology and Microbiology
# 21  Department of Immunology and Microbiology
# 22  Department of Immunology and Microbiology
# 23  Department of Immunology and Microbiology
# 24  Department of Immunology and Microbiology
# 25  Department of Immunology and Microbiology
# 26  Department of Immunology and Microbiology
# 27  Department of Immunology and Microbiology
# 28  Department of Immunology and Microbiology
# 29  Department of Immunology and Microbiology
# 30  Department of Immunology and Microbiology
#
#                                           center_name  \
# 0   Department of Immunology and Microbiology, Uni...
# 1   Department of Immunology and Microbiology, Uni...
# 2   Department of Immunology and Microbiology, Uni...
# 3   Department of Immunology and Microbiology, Uni...
# 4   Department of Immunology and Microbiology, Uni...
# 5   Department of Immunology and Microbiology, Uni...
# 6   Department of Immunology and Microbiology, Uni...
# 7   Department of Immunology and Microbiology, Uni...
# 8   Department of Immunology and Microbiology, Uni...
# 9   Department of Immunology and Microbiology, Uni...
# 10  Department of Immunology and Microbiology, Uni...
# 11  Department of Immunology and Microbiology, Uni...
# 12  Department of Immunology and Microbiology, Uni...
# 13  Department of Immunology and Microbiology, Uni...
# 14  Department of Immunology and Microbiology, Uni...
# 15  Department of Immunology and Microbiology, Uni...
# 16  Department of Immunology and Microbiology, Uni...
# 17  Department of Immunology and Microbiology, Uni...
# 18  Department of Immunology and Microbiology, Uni...
# 19  Department of Immunology and Microbiology, Uni...
# 20  Department of Immunology and Microbiology, Uni...
# 21  Department of Immunology and Microbiology, Uni...
# 22  Department of Immunology and Microbiology, Uni...
# 23  Department of Immunology and Microbiology, Uni...
# 24  Department of Immunology and Microbiology, Uni...
# 25  Department of Immunology and Microbiology, Uni...
# 26  Department of Immunology and Microbiology, Uni...
# 27  Department of Immunology and Microbiology, Uni...
# 28  Department of Immunology and Microbiology, Uni...
# 29  Department of Immunology and Microbiology, Uni...
# 30  Department of Immunology and Microbiology, Uni...
#
#                          first_authors_and_pi          pub_ids  \
# 0   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 1   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 2   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 3   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 4   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 5   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 6   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 7   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 8   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 9   D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 10  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 11  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 12  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 13  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 14  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 15  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 16  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 17  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 18  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 19  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 20  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 21  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 22  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 23  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 24  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 25  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 26  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 27  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 28  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 29  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
# 30  D. J. Munson, C.A. Egelston, J.E. Slansky  pubmed/27307436
#
#                           ...                         single_or_paired  \
# 0                         ...                                   paired
# 1                         ...                                   paired
# 2                         ...                                   paired
# 3                         ...                                   paired
# 4                         ...                                   paired
# 5                         ...                                   paired
# 6                         ...                                   paired
# 7                         ...                                   paired
# 8                         ...                                   paired
# 9                         ...                                   paired
# 10                        ...                                   paired
# 11                        ...                                   paired
# 12                        ...                                   paired
# 13                        ...                                   paired
# 14                        ...                                   paired
# 15                        ...                                   paired
# 16                        ...                                   paired
# 17                        ...                                   paired
# 18                        ...                                   paired
# 19                        ...                                   paired
# 20                        ...                                   paired
# 21                        ...                                   paired
# 22                        ...                                   paired
# 23                        ...                                   paired
# 24                        ...                                   paired
# 25                        ...                                   paired
# 26                        ...                                   paired
# 27                        ...                                   paired
# 28                        ...                                   paired
# 29                        ...                                   paired
# 30                        ...                                   paired
#
#    regions_included_in_sequence antigen  spot_descriptor  barcode_1 barcode_2  \
# 0                          CDR3      NaN             NaN        NaN       NaN
# 1                          CDR3      NaN             NaN        NaN       NaN
# 2                          CDR3      NaN             NaN        NaN       NaN
# 3                          CDR3      NaN             NaN        NaN       NaN
# 4                          CDR3      NaN             NaN        NaN       NaN
# 5                          CDR3      NaN             NaN        NaN       NaN
# 6                          CDR3      NaN             NaN        NaN       NaN
# 7                          CDR3      NaN             NaN        NaN       NaN
# 8                          CDR3      NaN             NaN        NaN       NaN
# 9                          CDR3      NaN             NaN        NaN       NaN
# 10                         CDR3      NaN             NaN        NaN       NaN
# 11                         CDR3      NaN             NaN        NaN       NaN
# 12                         CDR3      NaN             NaN        NaN       NaN
# 13                         CDR3      NaN             NaN        NaN       NaN
# 14                         CDR3      NaN             NaN        NaN       NaN
# 15                         CDR3      NaN             NaN        NaN       NaN
# 16                         CDR3      NaN             NaN        NaN       NaN
# 17                         CDR3      NaN             NaN        NaN       NaN
# 18                         CDR3      NaN             NaN        NaN       NaN
# 19                         CDR3      NaN             NaN        NaN       NaN
# 20                         CDR3      NaN             NaN        NaN       NaN
# 21                         CDR3      NaN             NaN        NaN       NaN
# 22                         CDR3      NaN             NaN        NaN       NaN
# 23                         CDR3      NaN             NaN        NaN       NaN
# 24                         CDR3      NaN             NaN        NaN       NaN
# 25                         CDR3      NaN             NaN        NaN       NaN
# 26                         CDR3      NaN             NaN        NaN       NaN
# 27                         CDR3      NaN             NaN        NaN       NaN
# 28                         CDR3      NaN             NaN        NaN       NaN
# 29                         CDR3      NaN             NaN        NaN       NaN
# 30                         CDR3      NaN             NaN        NaN       NaN
#
#      fasta_file_name  igblast_file_name  \
# 0   SRR3500416.fasta                NaN
# 1   SRR3500417.fasta                NaN
# 2   SRR3500418.fasta                NaN
# 3   SRR3500419.fasta                NaN
# 4   SRR3500420.fasta                NaN
# 5   SRR3500421.fasta                NaN
# 6   SRR3500422.fasta                NaN
# 7   SRR3500423.fasta                NaN
# 8   SRR3500424.fasta                NaN
# 9   SRR3500425.fasta                NaN
# 10  SRR3500426.fasta                NaN
# 11  SRR3500427.fasta                NaN
# 12  SRR3500428.fasta                NaN
# 13  SRR3500429.fasta                NaN
# 14  SRR3500430.fasta                NaN
# 15  SRR3500431.fasta                NaN
# 16  SRR3500432.fasta                NaN
# 17  SRR3500433.fasta                NaN
# 18  SRR3500434.fasta                NaN
# 19  SRR3500435.fasta                NaN
# 20  SRR3500436.fasta                NaN
# 21  SRR3500437.fasta                NaN
# 22  SRR3500438.fasta                NaN
# 23  SRR3500439.fasta                NaN
# 24  SRR3500440.fasta                NaN
# 25  SRR3500441.fasta                NaN
# 26  SRR3500442.fasta                NaN
# 27  SRR3500443.fasta                NaN
# 28  SRR3500444.fasta                NaN
# 29  SRR3500445.fasta                NaN
# 30  SRR3500446.fasta                NaN
#
#                                        imgt_file_name  \
# 0                  SRR3500416_a.txz, SRR3500416_b.txz
# 1   SRR3500417_a.txz, SRR3500417_b.txz, SRR3500417...
# 2                  SRR3500418_a.txz, SRR3500418_b.txz
# 3   SRR3500419_a.txz, SRR3500419_b.txz, SRR3500419...
# 4                  SRR3500420_a.txz, SRR3500420_b.txz
# 5   SRR3500421_a.txz, SRR3500421_b.txz, SRR3500421...
# 6   SRR3500422_a.txz, SRR3500422_b.txz, SRR3500422...
# 7   SRR3500423_a.txz, SRR3500423_b.txz, SRR3500423...
# 8   SRR3500424_a.txz, SRR3500424_b.txz, SRR3500424...
# 9   SRR3500425_a.txz, SRR3500425_b.txz, SRR3500425...
# 10  SRR3500426_a.txz, SRR3500426_b.txz, SRR3500426...
# 11                                     SRR3500427.txz
# 12  SRR3500428_a.txz, SRR3500428_b.txz, SRR3500428...
# 13                 SRR3500429_a.txz, SRR3500429_b.txz
# 14  SRR3500430_a.txz, SRR3500430_b.txz, SRR3500430...
# 15  SRR3500431_a.txz, SRR3500431_b.txz, SRR3500431...
# 16                 SRR3500432_a.txz, SRR3500432_b.txz
# 17  SRR3500433_a.txz, SRR3500433_b.txz, SRR3500433...
# 18  SRR3500434_a.txz, SRR3500434_b.txz, SRR3500434...
# 19  SRR3500435_a.txz, SRR3500435_b.txz, SRR3500435...
# 20  SRR3500436_a.txz, SRR3500436_b.txz, SRR3500436...
# 21  SRR3500437_a.txz, SRR3500437_b.txz, SRR3500437...
# 22  SRR3500438_a.txz, SRR3500438_b.txz, SRR3500438...
# 23  SRR3500439_a.txz, SRR3500439_b.txz, SRR3500439...
# 24                 SRR3500440_a.txz, SRR3500440_b.txz
# 25                 SRR3500441_a.txz, SRR3500441_b.txz
# 26  SRR3500442_a.txz, SRR3500442_b.txz, SRR3500442...
# 27                                     SRR3500443.txz
# 28  SRR3500444_a.txz, SRR3500444_b.txz, SRR3500444...
# 29                 SRR3500445_a.txz, SRR3500445_b.txz
# 30                 SRR3500446_a.txz, SRR3500446_b.txz
#
#                                       mixcr_file_name
# 0   SRR3500416_mixcr.vdjca, SRR3500416_annotation....
# 1   SRR3500417_mixcr.vdjca, SRR3500417_annotation....
# 2   SRR3500418_mixcr.vdjca, SRR3500418_annotation....
# 3   SRR3500419_mixcr.vdjca, SRR3500419_annotation....
# 4   SRR3500420_mixcr.vdjca, SRR3500420_annotation....
# 5   SRR3500421_mixcr.vdjca, SRR3500421_annotation....
# 6   SRR3500422_mixcr.vdjca, SRR3500422_annotation....
# 7   SRR3500423_mixcr.vdjca, SRR3500423_annotation....
# 8   SRR3500424_mixcr.vdjca, SRR3500424_annotation....
# 9   SRR3500425_mixcr.vdjca, SRR3500425_annotation....
# 10  SRR3500426_mixcr.vdjca, SRR3500426_annotation....
# 11  SRR3500427_mixcr.vdjca, SRR3500427_annotation....
# 12  SRR3500428_mixcr.vdjca, SRR3500428_annotation....
# 13  SRR3500429_mixcr.vdjca, SRR3500429_annotation....
# 14  SRR3500430_mixcr.vdjca, SRR3500430_annotation....
# 15  SRR3500431_mixcr.vdjca, SRR3500431_annotation....
# 16  SRR3500432_mixcr.vdjca, SRR3500432_annotation....
# 17  SRR3500433_mixcr.vdjca, SRR3500433_annotation....
# 18  SRR3500434_mixcr.vdjca, SRR3500434_annotation....
# 19  SRR3500435_mixcr.vdjca, SRR3500435_annotation....
# 20  SRR3500436_mixcr.vdjca, SRR3500436_annotation....
# 21  SRR3500437_mixcr.vdjca, SRR3500437_annotation....
# 22  SRR3500438_mixcr.vdjca, SRR3500438_annotation....
# 23  SRR3500439_mixcr.vdjca, SRR3500439_annotation....
# 24  SRR3500440_mixcr.vdjca, SRR3500440_annotation....
# 25  SRR3500441_mixcr.vdjca, SRR3500441_annotation....
# 26  SRR3500442_mixcr.vdjca, SRR3500442_annotation....
# 27  SRR3500443_mixcr.vdjca, SRR3500443_annotation....
# 28  SRR3500444_mixcr.vdjca, SRR3500444_annotation....
# 29  SRR3500445_mixcr.vdjca, SRR3500445_annotation....
# 30  SRR3500446_mixcr.vdjca, SRR3500446_annotation....
#
# [31 rows x 101 columns]

# %%
# Select columns of interest 

# Identify indeces where columns or interest are located
Zvy_runId_index = pd_Zvy.columns.get_loc("run_id")
Zvy_fasta_index = pd_Zvy.columns.get_loc("fasta_file_name")
Zvy_igblast_index = pd_Zvy.columns.get_loc("igblast_file_name")
Zvy_imgt_index = pd_Zvy.columns.get_loc("imgt_file_name")
Zvy_mixrc_index = pd_Zvy.columns.get_loc("mixcr_file_name")

# Store columns of interest in a single DataFrame
Zvy_fileNames = pd_Zvy.iloc[1:,[Zvy_runId_index,Zvy_fasta_index,Zvy_igblast_index,Zvy_imgt_index,Zvy_mixrc_index]]

# %%
# Visualize DataFrame

Zvy_fileNames
# Out:
#         run_id   fasta_file_name  igblast_file_name  \
# 1   SRR3500417  SRR3500417.fasta                NaN
# 2   SRR3500418  SRR3500418.fasta                NaN
# 3   SRR3500419  SRR3500419.fasta                NaN
# 4   SRR3500420  SRR3500420.fasta                NaN
# 5   SRR3500421  SRR3500421.fasta                NaN
# 6   SRR3500422  SRR3500422.fasta                NaN
# 7   SRR3500423  SRR3500423.fasta                NaN
# 8   SRR3500424  SRR3500424.fasta                NaN
# 9   SRR3500425  SRR3500425.fasta                NaN
# 10  SRR3500426  SRR3500426.fasta                NaN
# 11  SRR3500427  SRR3500427.fasta                NaN
# 12  SRR3500428  SRR3500428.fasta                NaN
# 13  SRR3500429  SRR3500429.fasta                NaN
# 14  SRR3500430  SRR3500430.fasta                NaN
# 15  SRR3500431  SRR3500431.fasta                NaN
# 16  SRR3500432  SRR3500432.fasta                NaN
# 17  SRR3500433  SRR3500433.fasta                NaN
# 18  SRR3500434  SRR3500434.fasta                NaN
# 19  SRR3500435  SRR3500435.fasta                NaN
# 20  SRR3500436  SRR3500436.fasta                NaN
# 21  SRR3500437  SRR3500437.fasta                NaN
# 22  SRR3500438  SRR3500438.fasta                NaN
# 23  SRR3500439  SRR3500439.fasta                NaN
# 24  SRR3500440  SRR3500440.fasta                NaN
# 25  SRR3500441  SRR3500441.fasta                NaN
# 26  SRR3500442  SRR3500442.fasta                NaN
# 27  SRR3500443  SRR3500443.fasta                NaN
# 28  SRR3500444  SRR3500444.fasta                NaN
# 29  SRR3500445  SRR3500445.fasta                NaN
# 30  SRR3500446  SRR3500446.fasta                NaN
#
#                                        imgt_file_name  \
# 1   SRR3500417_a.txz, SRR3500417_b.txz, SRR3500417...
# 2                  SRR3500418_a.txz, SRR3500418_b.txz
# 3   SRR3500419_a.txz, SRR3500419_b.txz, SRR3500419...
# 4                  SRR3500420_a.txz, SRR3500420_b.txz
# 5   SRR3500421_a.txz, SRR3500421_b.txz, SRR3500421...
# 6   SRR3500422_a.txz, SRR3500422_b.txz, SRR3500422...
# 7   SRR3500423_a.txz, SRR3500423_b.txz, SRR3500423...
# 8   SRR3500424_a.txz, SRR3500424_b.txz, SRR3500424...
# 9   SRR3500425_a.txz, SRR3500425_b.txz, SRR3500425...
# 10  SRR3500426_a.txz, SRR3500426_b.txz, SRR3500426...
# 11                                     SRR3500427.txz
# 12  SRR3500428_a.txz, SRR3500428_b.txz, SRR3500428...
# 13                 SRR3500429_a.txz, SRR3500429_b.txz
# 14  SRR3500430_a.txz, SRR3500430_b.txz, SRR3500430...
# 15  SRR3500431_a.txz, SRR3500431_b.txz, SRR3500431...
# 16                 SRR3500432_a.txz, SRR3500432_b.txz
# 17  SRR3500433_a.txz, SRR3500433_b.txz, SRR3500433...
# 18  SRR3500434_a.txz, SRR3500434_b.txz, SRR3500434...
# 19  SRR3500435_a.txz, SRR3500435_b.txz, SRR3500435...
# 20  SRR3500436_a.txz, SRR3500436_b.txz, SRR3500436...
# 21  SRR3500437_a.txz, SRR3500437_b.txz, SRR3500437...
# 22  SRR3500438_a.txz, SRR3500438_b.txz, SRR3500438...
# 23  SRR3500439_a.txz, SRR3500439_b.txz, SRR3500439...
# 24                 SRR3500440_a.txz, SRR3500440_b.txz
# 25                 SRR3500441_a.txz, SRR3500441_b.txz
# 26  SRR3500442_a.txz, SRR3500442_b.txz, SRR3500442...
# 27                                     SRR3500443.txz
# 28  SRR3500444_a.txz, SRR3500444_b.txz, SRR3500444...
# 29                 SRR3500445_a.txz, SRR3500445_b.txz
# 30                 SRR3500446_a.txz, SRR3500446_b.txz
#
#                                       mixcr_file_name
# 1   SRR3500417_mixcr.vdjca, SRR3500417_annotation....
# 2   SRR3500418_mixcr.vdjca, SRR3500418_annotation....
# 3   SRR3500419_mixcr.vdjca, SRR3500419_annotation....
# 4   SRR3500420_mixcr.vdjca, SRR3500420_annotation....
# 5   SRR3500421_mixcr.vdjca, SRR3500421_annotation....
# 6   SRR3500422_mixcr.vdjca, SRR3500422_annotation....
# 7   SRR3500423_mixcr.vdjca, SRR3500423_annotation....
# 8   SRR3500424_mixcr.vdjca, SRR3500424_annotation....
# 9   SRR3500425_mixcr.vdjca, SRR3500425_annotation....
# 10  SRR3500426_mixcr.vdjca, SRR3500426_annotation....
# 11  SRR3500427_mixcr.vdjca, SRR3500427_annotation....
# 12  SRR3500428_mixcr.vdjca, SRR3500428_annotation....
# 13  SRR3500429_mixcr.vdjca, SRR3500429_annotation....
# 14  SRR3500430_mixcr.vdjca, SRR3500430_annotation....
# 15  SRR3500431_mixcr.vdjca, SRR3500431_annotation....
# 16  SRR3500432_mixcr.vdjca, SRR3500432_annotation....
# 17  SRR3500433_mixcr.vdjca, SRR3500433_annotation....
# 18  SRR3500434_mixcr.vdjca, SRR3500434_annotation....
# 19  SRR3500435_mixcr.vdjca, SRR3500435_annotation....
# 20  SRR3500436_mixcr.vdjca, SRR3500436_annotation....
# 21  SRR3500437_mixcr.vdjca, SRR3500437_annotation....
# 22  SRR3500438_mixcr.vdjca, SRR3500438_annotation....
# 23  SRR3500439_mixcr.vdjca, SRR3500439_annotation....
# 24  SRR3500440_mixcr.vdjca, SRR3500440_annotation....
# 25  SRR3500441_mixcr.vdjca, SRR3500441_annotation....
# 26  SRR3500442_mixcr.vdjca, SRR3500442_annotation....
# 27  SRR3500443_mixcr.vdjca, SRR3500443_annotation....
# 28  SRR3500444_mixcr.vdjca, SRR3500444_annotation....
# 29  SRR3500445_mixcr.vdjca, SRR3500445_annotation....
# 30  SRR3500446_mixcr.vdjca, SRR3500446_annotation....

# %%
# Identify column names containing file names
file_type_names = ["fasta_file_name","igblast_file_name","imgt_file_name","mixcr_file_name"]

# %%
# Count how many files are there on each cell

file_number_count  = [[len(str(Zvy_fileNames.iloc[i].loc[file_type_names[j]]).split("."))-1 for j in range(len(file_type_names))]\
               for i in range(len(Zvy_fileNames))]

# %%
# Get a sense of how many files we are dealing with
print(file_number_count)
# Out:
# [[1, 0, 3, 4], [1, 0, 2, 4], [1, 0, 5, 4], [1, 0, 2, 4], [1, 0, 8, 4], [1, 0, 4, 4], [1, 0, 4, 4], [1, 0, 6, 4], [1, 0, 3, 4], [1, 0, 5, 4], [1, 0, 1, 4], [1, 0, 14, 4], [1, 0, 2, 4], [1, 0, 3, 4], [1, 0, 5, 4], [1, 0, 2, 4], [1, 0, 5, 4], [1, 0, 5, 4], [1, 0, 5, 4], [1, 0, 5, 4], [1, 0, 5, 4], [1, 0, 3, 4], [1, 0, 5, 4], [1, 0, 2, 4], [1, 0, 2, 4], [1, 0, 3, 4], [1, 0, 1, 4], [1, 0, 3, 4], [1, 0, 2, 4], [1, 0, 2, 4]]

# %% [markdown]
# To clarify what we did, we isolated the columns from the metadata spreadsheet that we are interested in. We then counted the number of files that were identified in each cell. A value 0 means that a NaN was found in that cell. A value greater than 0 denotes the total number of files in the cell. Files were found by counting the number of instances that contained a "." in them. The split() method was used to count.
#
# Now that we solved part 1) in our two steps, we can now begin to check whether or not our Run_ID is found in the file name.

# %%
# Empty array
all_arr = []

number_row  = len(file_number_count)

# For k from 0 to number of rows in our DataFrame (note this is equivalent to the number of entries
#   in the file_number_count array), do 
for k in range(number_row):

    #Create empty array 
    arr_ = []

    # Iterate over the number of files found in each cell
    for i in range(4):
        
        # If there were no files, i.e. NaN was the entry, then append False on arr_
        if file_number_count[k][i]==0:
            arr_.append(False)
            
        # Otherwise, let us check for how many of the files the condition is true
        else:

            # Create an array such that each entry corresponds to one file in the cell
            check_files= Zvy_fileNames.iloc[k].loc[file_type_names[i]].split(",")
            
            # Empty array to store True,False values
            val = []
            
            # For j from 0 to the total number of files in the cell
            for j in range(len(check_files)):
            
                # If run_id is contained in the file name, append True, otherwise append False
                if Zvy_fileNames.iloc[k].loc["run_id"] in Zvy_fileNames.iloc[k].loc[file_type_names[i]].split(",")[j]:
                    val.append(True)
                else:
                    val.append(False)
            # Store array with arrays containing True or False values
            arr_.append(val)
    # Store row array 
    all_arr.append(arr_)

# %%
# Print first entry
print(all_arr[0])
# Out:
# [[True], False, [True, True, True], [True, True, True, True]]

# %% [markdown]
# We see that in the first entry, the values
#
# [True], False, [True, True, True], [True, True, True, True]
#
# are found. Let us digest what this means.
#
# The first entry [True], indicates that only one file was found under fasta_file_name and the condition run_id in fasta_file_name is True. The second entry False indicates a NaN entry under igblast_file_name. The third entry [True, True, True] indicated that there were 3 files under imgt_filename and that run_id was found in all filenames. Similarly, the last entry [True, True, True,True] indicates 4 filenames under mixcr_file_name, all of which contained the corresponding run_id.
#
# Below is the entire test array.

# %%
for item in all_arr:
    print(item)
# Out:
# [[True], False, [True, True, True], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True, True, True, True, False], [True, True, True, True]]
# [[True], False, [True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True, True, True, True, True, True, True, True, True, True, False], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]
# [[True], False, [True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True], [True, True, True, True]]
# [[True], False, [True, True, True, True, True], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]
# [[True], False, [True, True, True], [True, True, True, True]]
# [[True], False, [True], [True, True, True, True]]
# [[True], False, [True, True, True], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]
# [[True], False, [True, True], [True, True, True, True]]

# %% [markdown]
# <h2 align='center'>Generalize</h2>
#
# Now we wish to apply this onto other metadata spreadsheets. We generalize the exercise performed above.

# %%
def get_metadata_spreadsheet(full_filename):
    
    pd_metadata = pd.read_excel(full_filename)
    
    return pd_metadata


def get_file_columns(full_filename):
    
    pd_metadata = get_metadata_spreadsheet(full_filename)
    
    pd_metadata_runId_index = pd_metadata.columns.get_loc("run_id")
    
    pd_metadata_fasta_index = pd_metadata.columns.get_loc("fasta_file_name")
    
    pd_metadata_igblast_index = pd_metadata.columns.get_loc("igblast_file_name")
    
    pd_metadata_imgt_index = pd_metadata.columns.get_loc("imgt_file_name")
    
    pd_metadata_mixrc_index = pd_metadata.columns.get_loc("mixcr_file_name")
    

    # Store columns of interest in a single DataFrame
    metadata_fileNames = pd_metadata.iloc[1:,[pd_metadata_runId_index,pd_metadata_fasta_index,\
                                      pd_metadata_igblast_index,pd_metadata_imgt_index,\
                                      pd_metadata_mixrc_index]]
    return metadata_fileNames

def count_number_files_per_cell(full_filename):
    
    file_type_names = ["fasta_file_name","igblast_file_name","imgt_file_name","mixcr_file_name"]
    
    metadata_fileNames = get_file_columns(full_filename)
    
    
    file_number_count  = [[len(str(metadata_fileNames.iloc[i].loc[file_type_names[j]]).split("."))-1 \
                           for j in range(len(file_type_names))]\
               for i in range(len(metadata_fileNames))]
    return file_number_count


def verify_filename_contains_runId(full_filename):
    
    
    metadata_fileNames = get_file_columns(full_filename)
    file_number_count = count_number_files_per_cell(full_filename)
    
    # Empty array
    all_arr = []

    number_row  = len(file_number_count)

    # For k from 0 to number of rows in our DataFrame (note this is equivalent to the number of entries
    #   in the file_number_count array), do 
    for k in range(number_row):

    #Create empty array 
        arr_ = []

    # Iterate over the number of files found in each cell
        for i in range(4):
        
        # If there were no files, i.e. NaN was the entry, then append False on arr_
            if file_number_count[k][i]==0:
                arr_.append(False)
            
        # Otherwise, let us check for how many of the files the condition is true
            else:

            # Create an array such that each entry corresponds to one file in the cell
                check_files= metadata_fileNames.iloc[k].loc[file_type_names[i]].split(",")
            
            # Empty array to store True,False values
                val = []
            
            # For j from 0 to the total number of files in the cell
                for j in range(len(check_files)):
            
                # If run_id is contained in the file name, append True, otherwise append False
                    if metadata_fileNames.iloc[k].loc["run_id"] in \
                    metadata_fileNames.iloc[k].loc[file_type_names[i]].split(",")[j]:
                        val.append(True)
                    else:
                        val.append(False)
            # Store array with arrays containing True or False values
                arr_.append(val)
    # Store row array 
        all_arr.append(arr_)        
    return all_arr

# %%
verify_filename_contains_runId(Zvy)
# Out:
# [[[True], False, False, [True, True]],
#  [[False], False, False, [False, False]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]],
#  [[True], False, False, [True, True]]]
